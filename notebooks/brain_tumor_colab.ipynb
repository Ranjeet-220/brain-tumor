# %% [markdown]
# # Brain Tumor Detection - Google Colab Training
#
# This notebook clones the repository, sets up the dataset, and runs the training pipeline.

# %%
# 1. Clone Repository
# !git clone https://github.com/Ranjeet-220/brain-tumor.git
# %cd brain-tumor

# %%
# 2. Install Dependencies
# !pip install -r requirements.txt

# %%
# 3. Download Dataset
# This script handles downloading from KaggleHub and cleaning up paths
# !python src/download_data.py

# %%
# 4. Run Training
# !python src/train.py

# %%
# 5. Check Output
# !ls models/
